# %%
systemp_prompt ="""
<Requirements>
You are an expert in processing and reading markdown information from documents. Your tasks:
1. Analyze the user-provided markdown text.
2. Extract information as JSON Schema.
3. Strictly adhere to:
   - Fill `null` for fields without available information
   - Date format: "YYYY-MM-DD" for dates, "YYYY-MM-DDTHH:mm:ss" for date-times
   - Enum values MUST be integers as described
   - Use empty arrays `[]` if no elements exist
   - Do NOT add extra fields outside the schema
   - CRITICAL: Handle duplicate information between BenGiao and BenNhan:
        * For each BenGiao entry, check if name + address matches any BenNhan entry
        * IF DUPLICATE: COMPLETELY REMOVE that BenGiao entry from the array
        * Duplication criteria: Exact string match of name + address

Return ONLY valid JSON output without explanations.
</Requirements>"""

# %%
# import lmstudio as lms
# import json

# SERVER_API_HOST = "localhost:8502"

# # This must be the *first* convenience API interaction (otherwise the SDK
# # implicitly creates a client that accesses the default server API host)
# lms.configure_default_client(SERVER_API_HOST)


# # model = lms.llm("gemma-3-12b-it-qat", config={"seed": 5315813802286225740, "flashAttention": True, "evalBatchSize": 7096, "contextLength": 7096})
# model = lms.llm(
#     "qwen/qwen3-4b",
#     config={
#         "seed": 5315813802286225740,
#         "flashAttention": True,
#         "evalBatchSize": 2096,
#         "contextLength": 4096,
#         "offloadKVCacheToGpu": False, 
#         "keepModelInMemory": False, 
#         "tryMmap": False
#     },
# )
# def get_json(prompt: str):
#     chat = lms.Chat("You are a helpful assistant")
#     chat.add_user_message(prompt)
#     prediction = model.respond(chat,  config={"temperature": 0.2}, response_format=schema)
#     print(prediction.content)
#     # value = json.loads(
#     #     prediction.content.replace("```json", "").replace("```", "").strip()
#     # )
#     # for key in value:
#     #     if isinstance(value[key], list):
#     #         merge_list = {}
#     #         for item in value[key]:
#     #             if isinstance(item, dict):
#     #                 merge_list.update(item)
#     #         value[key] = merge_list
            
#     # print(value)
#     return prediction

# %% [markdown]
# ## Convert to Md

# %%
# if True:
#     from unsloth import FastModel
#     model, tokenizer = FastModel.from_pretrained(
#         model_name = "/home/duckq1u/Documents/obsidian_aio/Notebook/Dự án/OCR anh hiếu/OCR/gemma-3-Markdown2Json-ver2", # YOUR MODEL YOU USED FOR TRAINING
#         max_seq_length = 4096,
#         load_in_8bit = True,
#         load_in_4bit= False,
        
        
#     )

# %%
from marker.converters.pdf import PdfConverter
from marker.models import create_model_dict
from marker.config.parser import ConfigParser

config = {
    "output_format": "markdown",
    "use_llm": False,
    "gemini_api_key": "AIzaSyBkRQB1MTbXbHdDvphv1ID5bkejT7QEDyE",
    "gemini_model_name": "gemini-2.5-flash",
}
config_parser = ConfigParser(config)

converter = PdfConverter(
    config=config_parser.generate_config_dict(),
    artifact_dict=create_model_dict(),
    processor_list=config_parser.get_processors(),
    renderer=config_parser.get_renderer(),
    llm_service=config_parser.get_llm_service()
)

# %%
folder_path = (
    "/mnt/SSD-playing games/Workspace/obsidian_aio/Notebook/Dự án/OCR anh hiếu/dataset/1"
)

def read_txt(file_path: str) -> str:
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()
    return content

# 1597891480
# read file in folder
import os
import requests
from marker.output import text_from_rendered

for filename in os.listdir(folder_path):
    if filename.endswith(".pdf"):
        source = os.path.join(folder_path, filename)
        # read file in folder --- IGNORE ---
        print("-"*70, filename, "-"*70)
        rendered = converter(source)
        text, _, images = text_from_rendered(rendered)
        # show image size resolution
        # prompt = f"return JSON for me from <RAW TEXT FROM IMAGE> {text} </RAW TEXT FROM IMAGE>"
        # get_json(prompt)
        with open(os.path.join(folder_path,filename.replace('.pdf', '.txt')), "w", encoding="utf-8") as f:
            f.write(text)
        # md = read_txt(source)
        # messages = [{
        #     "role": "user",
        #     "content": [{
        #         "type" : "text",
        #         "text" : f"<context>{str(md)}</context>\n<requirement>\n Return information extracted from Markdown as JSON for me </requirement>\n\n\n"
        #     }]
        # }]


        # text = tokenizer.apply_chat_template(
        #     messages,
        #     add_generation_prompt = True, # Must add for generation
        # )

        # from transformers import TextStreamer
        # _ = model.generate(
        #     **tokenizer([text], return_tensors = "pt").to("cuda"),
        #     max_new_tokens = 5069, # Increase for longer outputs!
        #     # Recommended Gemma-3 settings!
        #     temperature = 0.4, top_p = 0.95, top_k = 64,
        #     streamer = TextStreamer(tokenizer, skip_prompt = True),
        # )
# Out:
# ---------------------------------------------------------------------- 1597868985.pdf ----------------------------------------------------------------------
# ...
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# Detecting bboxes: 0it [00:00, ?it/s]
# Recognizing tables: 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
